# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
g = nx.read_gml('/home/dheeraj/my_projects/my_project_env/practice/6th_sem_Academics/SocialNetworkAnalysis/HandsOn/epidemic/karate.gml',label='label', destringizer=None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/my_projects/my_project_env/lib/python3.6/site-packages/networkx/readwrite/gml.py in pop_attr(dct, category, attr, i)
#     427         try:
# --> 428             return dct.pop(attr)
#     429         except KeyError:
#
# KeyError: 'label'
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-5-e853c1ab018c> in <module>
# ----> 1 g = nx.read_gml('/home/dheeraj/my_projects/my_project_env/practice/6th_sem_Academics/SocialNetworkAnalysis/HandsOn/epidemic/karate.gml',label='label', destringizer=None)
#
# </home/dheeraj/my_projects/my_project_env/lib/python3.6/site-packages/decorator.py:decorator-gen-777> in read_gml(path, label, destringizer)
#
# ...
