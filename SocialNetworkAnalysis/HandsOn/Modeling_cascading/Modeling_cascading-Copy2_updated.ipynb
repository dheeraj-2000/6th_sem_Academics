# %%
#import igraph
#from igraph import *
import matplotlib.pyplot as plt
import networkx as nx

# %%
#g = nx.erdos_renyi_graph(10, 0.5)
#nx.write_gml(g, '/home/dheeraj/my_projects/my_project_env/practice/6th_sem_Academics/SocialNetworkAnalysis/HandsOn/Modeling_cascading/main_graph.gml')

# %%
t = int(input('Enter Number of Test cases: '))
g = nx.erdos_renyi_graph(20, 0.5)

#g = nx.read_gml('/home/dheeraj/my_projects/my_project_env/practice/6th_sem_Academics/SocialNetworkAnalysis/HandsOn/Modeling_cascading/main_graph.gml')

while(t):
    
    b = int(input('Enter PAYOFF for Initial bahaviour: '))
    a = int(input('Enter PAYOFF for New bahaviour: '))
   
    def col_fun(g):
        infected_seed=[]
        for each in g.nodes():
            if g.nodes[each]['behaviour']=='initial_behaviour':
                infected_seed.append('yellow')
            else:
                infected_seed.append('green')
        return infected_seed

    def find_neigh(each, c, g):
        num=0
        for each1 in g.neighbors(each):
            if g.nodes[each1]['behaviour']==c:
                num=num+1
        return num

    def recalculate_options(g):
        dict1= {}
        #Payoff(A) =a=4
        #Payoff(B) =b=3
        #a=5
        #b=2
       # a = int(input('Enter payoff for new bahaviour: '))
        #b = int(input('Enter payoff for initial bahaviour: '))
        for each in g.nodes():
            num_A = find_neigh(each, 'new_behaviour', g)
            num_B = find_neigh(each, 'initial_behaviour', g)
            payoff_A=a*num_A
            payoff_B=b*num_B
            if payoff_A >= payoff_B:
                dict1[each]='new_behaviour'
            else:
                dict1[each]= 'initial_behaviour'
        return dict1

    def reset_node_attributes(g, behaviour_di):
        for each in behaviour_di:
            g.nodes[each]['behaviour']= behaviour_di[each]
        
    def terminate_1(c, g):
        f=1
        for each in g.nodes():
            if g.nodes[each]['behaviour']!=c:
                f=0
                break
        return f

    def terminate(g, count):
        flag1=terminate_1('new_behaviour', g)
        flag2=terminate_1('initial_behaviour',g)
        if flag1==1 or flag2==1 or count>=100:
            return 1
        else:
            return 0
    

    external_behaviour = "new_behaviour"
    bahaviour_1 = "initial_behaviour"
    for each in g.nodes():
        g.nodes[each]['behaviour'] = bahaviour_1
    
    #n1 = input()
    #n2 = input()
    #infected_seed = [2,5,8]
    infected_seed = []
    n= int(input("Enter number of inital seeds: "))

    for i in range(0,n):
        seed_val = int(input('Enter seed value: '))
        infected_seed.append(seed_val)
    
    print('Initial seed input is: ', infected_seed)
    
    
    

    for each in infected_seed:
        g.nodes[each]['behaviour'] = external_behaviour 
    
    #colors = col_fun(g)

    #a = input("payoff for A: ")
    #b= input("payoff for B: ")
    temp =0
    count =0
    while(1):
        temp = terminate(g, count)
        if temp==1:
            break
        count = count+1
        behaviour_di  = recalculate_options(g)
        reset_node_attributes(g, behaviour_di)
        colors = col_fun(g)

    c =terminate_1('new_behaviour', g)
    if c==1:
        print('cascade is COMPLETE ( with cascading size of: ', len(g),')')
    else:
        print('cascade is incomplete') 
        for i in g.nodes():
            if(g.nodes[each]['behaviour'] == "new_behaviour"):
                count = count +1
            print(count)

    nx.draw(g,node_color= colors , node_size=1200,with_labels=True)
    plt.show()
    t=t-1
# Out:
# Enter Number of Test cases: 2
# Enter PAYOFF for Initial bahaviour: 1
# Enter PAYOFF for New bahaviour: 6
# Enter number of inital seeds: 2
# Enter seed value: 3
# Enter seed value: 5
# Initial seed input is:  [3, 5]
# cascade is COMPLETE ( with cascading size of:  20 )
# Enter PAYOFF for Initial bahaviour: 1
# Enter PAYOFF for New bahaviour: 6
# Enter number of inital seeds: 2
# Enter seed value: 7
# Enter seed value: 8
# Initial seed input is:  [7, 8]
# cascade is COMPLETE ( with cascading size of:  20 )

# %%
## g = nx.read_gml('/home/dheeraj/my_projects/my_project_env/practice/6th_sem_Academics/SocialNetworkAnalysis/HandsOn/Modeling_cascading/main_graph.gml')

# %%
#nx.draw(g, with_labels=True)

# %%
#set_all_B(g)

# %%
#list1=[2,5]

# %%
#colors= get_colors(g)

# %%
#nx.draw(g, node_color = colors, node_size=800, with_labels=True)
#plt.show()

# %%
#g = nx.parse_edgelist('/home/dheeraj/my_projects/my_project_env/practice/6th_sem_Academics/SocialNetworkAnalysis/HandsOn/Modeling_cascading/mygraph.csv')

# %%
#g = nx.erdos_renyi_graph(20, 0.5)

# %%
#len(g)
# Out:
# 20

# %%
#g.nodes[1]
# Out:
# {'action': 'A'}

# %%
#action_dict  = recalculate_options(g)

# %%
#reset_node_attributes(g, action_dict)

# %%
#colors = get_colors(g)

# %%
#nx.draw(g,node_color= colors , node_size=800,with_labels=True)
#plt.show()

# %%
t = int(input('Enter Number of Test cases: '))
g = nx.erdos_renyi_graph(20, 0.5)

#g = nx.read_gml('/home/dheeraj/my_projects/my_project_env/practice/6th_sem_Academics/SocialNetworkAnalysis/HandsOn/Modeling_cascading/main_graph.gml')

while(t):
    
    b = int(input('Enter PAYOFF for Initial bahaviour: '))
    a = int(input('Enter PAYOFF for New bahaviour: '))
    
    def col_fun(g):
        infected_seed=[]
        for each in g.nodes():
            if g.nodes[each]['behaviour']=='initial_behaviour':
                infected_seed.append('yellow')
            else:
                infected_seed.append('green')
        return infected_seed

    def find_neigh(each, c, g):
        num=0
        for each1 in g.neighbors(each):
            if g.nodes[each1]['behaviour']==c:
                num=num+1
        return num

    def recalculate_options(g):
        dict1= {}
        #Payoff(A) =a=4
        #Payoff(B) =b=3
        #a=5
        #b=2
       # a = int(input('Enter payoff for new bahaviour: '))
        #b = int(input('Enter payoff for initial bahaviour: '))
        for each in g.nodes():
            num_A = find_neigh(each, 'new_behaviour', g)
            num_B = find_neigh(each, 'initial_behaviour', g)
            payoff_A=a*num_A
            payoff_B=b*num_B
            if payoff_A >= payoff_B:
                dict1[each]='new_behaviour'
            else:
                dict1[each]= 'initial_behaviour'
        return dict1

    def reset_node_attributes(g, behaviour_di):
        for each in behaviour_di:
            g.nodes[each]['behaviour']= behaviour_di[each]
        
    def terminate_1(c, g):
        f=1
        for each in g.nodes():
            if g.nodes[each]['behaviour']!=c:
                f=0
                break
        return f

    def terminate(g, count):
        flag1=terminate_1('new_behaviour', g)
        flag2=terminate_1('initial_behaviour',g)
        if flag1==1 or flag2==1 or count>=100:
            return 1
        else:
            return 0
    


        
    for u in g.nodes():
        for v in g.nodes():
            if u<v:
                print(u,v, ':')
                infected_seed = []
                infected_seed.append(u)
                infected_seed.append(v)
            
            
                external_behaviour = "new_behaviour"
                bahaviour_1 = "initial_behaviour"
                for each in g.nodes():
                    g.nodes[each]['behaviour'] = bahaviour_1
    

                for each in infected_seed:
                    g.nodes[each]['behaviour'] = external_behaviour 
                
                temp =0
                count =0
                while(1):
                    temp = terminate(g, count)
                    if temp==1:
                        break
                    count = count+1
                    behaviour_di  = recalculate_options(g)
                    reset_node_attributes(g, behaviour_di)
                    colors = col_fun(g)

                c =terminate_1('new_behaviour', g)
                if c==1:
                    print('cascade complete with size: ', len(g))
                else:
                    print('cascade incomplete')
                    count =0
                    for i in g.nodes():
                        if(g.nodes[each]['behaviour'] == "new_behaviour"):
                            count = count +1
                    print(count)
# Out:
# Enter Number of Test cases: 2
# Enter PAYOFF for Initial bahaviour: 3
# Enter PAYOFF for New bahaviour: 4
# 0 1 :
# cascade incomplete
# 0
# 0 2 :
# cascade incomplete
# 0
# 0 3 :
# cascade incomplete
# 0
# 0 4 :
# cascade incomplete
# 0
# 0 5 :
# cascade incomplete
# 0
# 0 6 :
# cascade incomplete
# 0
# 0 7 :
# cascade incomplete
# 0
# 0 8 :
# cascade incomplete
# 0
# 0 9 :
# cascade incomplete
# 0
# 0 10 :
# cascade incomplete
# 0
# 0 11 :
# cascade incomplete
# 0
# 0 12 :
# cascade incomplete
# 0
# 0 13 :
# cascade incomplete
# 0
# 0 14 :
# cascade incomplete
# 0
# 0 15 :
# cascade incomplete
# 0
# 0 16 :
# cascade incomplete
# 0
# 0 17 :
# cascade incomplete
# 0
# 0 18 :
# cascade incomplete
# 0
# 0 19 :
# cascade incomplete
# 0
# 1 2 :
# cascade incomplete
# 0
# 1 3 :
# cascade incomplete
# 0
# 1 4 :
# cascade incomplete
# 0
# 1 5 :
# cascade incomplete
# 0
# 1 6 :
# cascade incomplete
# 0
# 1 7 :
# cascade incomplete
# 0
# 1 8 :
# cascade incomplete
# 0
# 1 9 :
# cascade incomplete
# 0
# 1 10 :
# cascade incomplete
# 0
# 1 11 :
# cascade incomplete
# 0
# 1 12 :
# cascade incomplete
# 0
# 1 13 :
# cascade incomplete
# 0
# 1 14 :
# cascade incomplete
# 0
# 1 15 :
# cascade incomplete
# 0
# 1 16 :
# cascade incomplete
# 0
# 1 17 :
# cascade incomplete
# 0
# 1 18 :
# cascade incomplete
# 0
# 1 19 :
# cascade incomplete
# 0
# 2 3 :
# cascade incomplete
# 0
# 2 4 :
# cascade incomplete
# 0
# 2 5 :
# cascade incomplete
# 0
# 2 6 :
# cascade incomplete
# 0
# 2 7 :
# cascade incomplete
# 0
# 2 8 :
# cascade incomplete
# 0
# 2 9 :
# cascade incomplete
# 0
# 2 10 :
# cascade incomplete
# 0
# 2 11 :
# cascade incomplete
# 0
# 2 12 :
# cascade incomplete
# 0
# 2 13 :
# cascade incomplete
# 0
# 2 14 :
# cascade incomplete
# 0
# 2 15 :
# cascade incomplete
# 0
# 2 16 :
# cascade incomplete
# 0
# 2 17 :
# cascade incomplete
# 0
# 2 18 :
# cascade incomplete
# 0
# 2 19 :
# cascade incomplete
# 0
# 3 4 :
# cascade incomplete
# 0
# 3 5 :
# cascade incomplete
# 0
# 3 6 :
# cascade incomplete
# 0
# 3 7 :
# cascade incomplete
# 0
# 3 8 :
# cascade incomplete
# 0
# 3 9 :
# cascade incomplete
# 0
# 3 10 :
# cascade incomplete
# 0
# 3 11 :
# cascade incomplete
# 0
# 3 12 :
# cascade incomplete
# 0
# 3 13 :
# cascade incomplete
# 0
# 3 14 :
# cascade incomplete
# 0
# 3 15 :
# cascade incomplete
# 0
# 3 16 :
# cascade incomplete
# 0
# 3 17 :
# cascade incomplete
# 0
# 3 18 :
# cascade incomplete
# 0
# 3 19 :
# cascade incomplete
# 0
# 4 5 :
# cascade incomplete
# 0
# 4 6 :
# cascade incomplete
# 0
# 4 7 :
# cascade incomplete
# 0
# 4 8 :
# cascade incomplete
# 0
# 4 9 :
# cascade incomplete
# 0
# 4 10 :
# cascade incomplete
# 0
# 4 11 :
# cascade incomplete
# 0
# 4 12 :
# cascade incomplete
# 0
# 4 13 :
# cascade incomplete
# 0
# 4 14 :
# cascade incomplete
# 0
# 4 15 :
# cascade incomplete
# 0
# 4 16 :
# cascade incomplete
# 0
# 4 17 :
# cascade incomplete
# 0
# 4 18 :
# cascade incomplete
# 0
# 4 19 :
# cascade incomplete
# 0
# 5 6 :
# cascade incomplete
# 0
# 5 7 :
# cascade incomplete
# 0
# 5 8 :
# cascade incomplete
# 0
# 5 9 :
# cascade incomplete
# 0
# 5 10 :
# cascade incomplete
# 0
# 5 11 :
# cascade incomplete
# 0
# 5 12 :
# cascade incomplete
# 0
# 5 13 :
# cascade incomplete
# 0
# 5 14 :
# cascade incomplete
# 0
# 5 15 :
# cascade incomplete
# 0
# 5 16 :
# cascade incomplete
# 0
# 5 17 :
# cascade incomplete
# 0
# 5 18 :
# cascade incomplete
# 0
# 5 19 :
# cascade incomplete
# 0
# 6 7 :
# cascade incomplete
# 0
# 6 8 :
# cascade incomplete
# 0
# 6 9 :
# cascade incomplete
# 0
# 6 10 :
# cascade incomplete
# 0
# 6 11 :
# cascade incomplete
# 0
# 6 12 :
# cascade incomplete
# 0
# 6 13 :
# cascade incomplete
# 0
# 6 14 :
# cascade incomplete
# 0
# 6 15 :
# cascade incomplete
# 0
# 6 16 :
# cascade incomplete
# 0
# 6 17 :
# cascade incomplete
# 0
# 6 18 :
# cascade incomplete
# 0
# 6 19 :
# cascade incomplete
# 0
# 7 8 :
# cascade incomplete
# 0
# 7 9 :
# cascade incomplete
# 0
# 7 10 :
# cascade incomplete
# 0
# 7 11 :
# cascade incomplete
# 0
# 7 12 :
# cascade incomplete
# 0
# 7 13 :
# cascade incomplete
# 0
# 7 14 :
# cascade incomplete
# 0
# 7 15 :
# cascade incomplete
# 0
# 7 16 :
# cascade incomplete
# 0
# 7 17 :
# cascade incomplete
# 0
# 7 18 :
# cascade incomplete
# 0
# 7 19 :
# cascade incomplete
# 0
# 8 9 :
# cascade incomplete
# 0
# 8 10 :
# cascade incomplete
# 0
# 8 11 :
# cascade incomplete
# 0
# 8 12 :
# cascade incomplete
# 0
# 8 13 :
# cascade incomplete
# 0
# 8 14 :
# cascade incomplete
# 0
# 8 15 :
# cascade incomplete
# 0
# 8 16 :
# cascade incomplete
# 0
# 8 17 :
# cascade incomplete
# 0
# 8 18 :
# cascade incomplete
# 0
# 8 19 :
# cascade incomplete
# 0
# 9 10 :
# cascade incomplete
# 0
# 9 11 :
# cascade incomplete
# 0
# 9 12 :
# cascade incomplete
# 0
# 9 13 :
# cascade incomplete
# 0
# 9 14 :
# cascade incomplete
# 0
# 9 15 :
# cascade incomplete
# 0
# 9 16 :
# cascade incomplete
# 0
# 9 17 :
# cascade incomplete
# 0
# 9 18 :
# cascade incomplete
# 0
# 9 19 :
# cascade incomplete
# 0
# 10 11 :
# cascade incomplete
# 0
# 10 12 :
# cascade incomplete
# 0
# 10 13 :
# cascade incomplete
# 0
# 10 14 :
# cascade incomplete
# 0
# 10 15 :
# cascade incomplete
# 0
# 10 16 :
# cascade incomplete
# 0
# 10 17 :
# cascade incomplete
# 0
# 10 18 :
# cascade incomplete
# 0
# 10 19 :
# cascade incomplete
# 0
# 11 12 :
# cascade incomplete
# 0
# 11 13 :
# cascade incomplete
# 0
# 11 14 :
# cascade incomplete
# 0
# 11 15 :
# cascade incomplete
# 0
# 11 16 :
# cascade incomplete
# 0
# 11 17 :
# cascade incomplete
# 0
# 11 18 :
# cascade incomplete
# 0
# 11 19 :
# cascade incomplete
# 0
# 12 13 :
# cascade incomplete
# 0
# 12 14 :
# cascade incomplete
# 0
# 12 15 :
# cascade incomplete
# 0
# 12 16 :
# cascade incomplete
# 0
# 12 17 :
# cascade incomplete
# 0
# 12 18 :
# cascade incomplete
# 0
# 12 19 :
# cascade incomplete
# 0
# 13 14 :
# cascade incomplete
# 0
# 13 15 :
# cascade incomplete
# 0
# 13 16 :
# cascade incomplete
# 0
# 13 17 :
# cascade incomplete
# 0
# 13 18 :
# cascade incomplete
# 0
# 13 19 :
# cascade incomplete
# 0
# 14 15 :
# cascade incomplete
# 0
# 14 16 :
# cascade incomplete
# 0
# 14 17 :
# cascade incomplete
# 0
# 14 18 :
# cascade incomplete
# 0
# 14 19 :
# cascade incomplete
# 0
# 15 16 :
# cascade incomplete
# 0
# 15 17 :
# cascade incomplete
# 0
# 15 18 :
# cascade incomplete
# 0
# 15 19 :
# cascade incomplete
# 0
# 16 17 :
# cascade incomplete
# 0
# 16 18 :
# cascade incomplete
# 0
# 16 19 :
# cascade incomplete
# 0
# 17 18 :
# cascade incomplete
# 0
# 17 19 :
# cascade incomplete
# 0
# 18 19 :
# cascade incomplete
# 0
# Enter PAYOFF for Initial bahaviour: 2
# Enter PAYOFF for New bahaviour: 6
# 0 1 :
# cascade incomplete
# 0
# 0 2 :
# cascade incomplete
# 0
# 0 3 :
# cascade incomplete
# 0
# 0 4 :
# cascade incomplete
# 0
# 0 5 :
# cascade incomplete
# 0
# 0 6 :
# cascade incomplete
# 0
# 0 7 :
# cascade incomplete
# 0
# 0 8 :
# cascade incomplete
# 0
# 0 9 :
# cascade incomplete
# 0
# 0 10 :
# cascade incomplete
# 0
# 0 11 :
# cascade incomplete
# 0
# 0 12 :
# cascade incomplete
# 0
# 0 13 :
# cascade incomplete
# 0
# 0 14 :
# cascade incomplete
# 0
# 0 15 :
# cascade incomplete
# 0
# 0 16 :
# cascade incomplete
# 0
# 0 17 :
# cascade incomplete
# 0
# 0 18 :
# cascade incomplete
# 0
# 0 19 :
# cascade incomplete
# 0
# 1 2 :
# cascade incomplete
# 0
# 1 3 :
# cascade incomplete
# 20
# 1 4 :
# cascade incomplete
# 0
# 1 5 :
# cascade incomplete
# 0
# 1 6 :
# cascade incomplete
# 0
# 1 7 :
# cascade incomplete
# 0
# 1 8 :
# cascade incomplete
# 0
# 1 9 :
# cascade incomplete
# 0
# 1 10 :
# cascade incomplete
# 0
# 1 11 :
# cascade incomplete
# 0
# 1 12 :
# cascade incomplete
# 0
# 1 13 :
# cascade incomplete
# 0
# 1 14 :
# cascade incomplete
# 0
# 1 15 :
# cascade complete with size:  20
# 1 16 :
# cascade incomplete
# 0
# 1 17 :
# cascade complete with size:  20
# 1 18 :
# cascade incomplete
# 0
# 1 19 :
# cascade incomplete
# 0
# 2 3 :
# cascade incomplete
# 0
# 2 4 :
# cascade incomplete
# 0
# 2 5 :
# cascade incomplete
# 0
# 2 6 :
# cascade incomplete
# 0
# 2 7 :
# cascade incomplete
# 0
# 2 8 :
# cascade incomplete
# 0
# 2 9 :
# cascade incomplete
# 0
# 2 10 :
# cascade complete with size:  20
# 2 11 :
# cascade complete with size:  20
# 2 12 :
# cascade incomplete
# 0
# 2 13 :
# cascade incomplete
# 20
# 2 14 :
# cascade incomplete
# 0
# 2 15 :
# cascade incomplete
# 0
# 2 16 :
# cascade incomplete
# 0
# 2 17 :
# cascade complete with size:  20
# 2 18 :
# cascade incomplete
# 0
# 2 19 :
# cascade incomplete
# 20
# 3 4 :
# cascade incomplete
# 0
# 3 5 :
# cascade incomplete
# 0
# 3 6 :
# cascade incomplete
# 0
# 3 7 :
# cascade incomplete
# 0
# 3 8 :
# cascade incomplete
# 0
# 3 9 :
# cascade incomplete
# 0
# 3 10 :
# cascade incomplete
# 0
# 3 11 :
# cascade incomplete
# 20
# 3 12 :
# cascade incomplete
# 0
# 3 13 :
# cascade incomplete
# 0
# 3 14 :
# cascade incomplete
# 0
# 3 15 :
# cascade incomplete
# 20
# 3 16 :
# cascade incomplete
# 0
# 3 17 :
# cascade incomplete
# 0
# 3 18 :
# cascade incomplete
# 0
# 3 19 :
# cascade incomplete
# 20
# 4 5 :
# cascade incomplete
# 0
# 4 6 :
# cascade incomplete
# 0
# 4 7 :
# cascade incomplete
# 0
# 4 8 :
# cascade incomplete
# 0
# 4 9 :
# cascade incomplete
# 0
# 4 10 :
# cascade incomplete
# 0
# 4 11 :
# cascade incomplete
# 0
# 4 12 :
# cascade incomplete
# 20
# 4 13 :
# cascade incomplete
# 0
# 4 14 :
# cascade incomplete
# 20
# 4 15 :
# cascade complete with size:  20
# 4 16 :
# cascade incomplete
# 0
# 4 17 :
# cascade incomplete
# 0
# 4 18 :
# cascade incomplete
# 20
# 4 19 :
# cascade incomplete
# 0
# 5 6 :
# cascade incomplete
# 0
# 5 7 :
# cascade incomplete
# 0
# 5 8 :
# cascade incomplete
# 0
# 5 9 :
# cascade incomplete
# 0
# 5 10 :
# cascade incomplete
# 0
# 5 11 :
# cascade incomplete
# 0
# 5 12 :
# cascade incomplete
# 0
# 5 13 :
# cascade incomplete
# 0
# 5 14 :
# cascade incomplete
# 0
# 5 15 :
# cascade incomplete
# 0
# 5 16 :
# cascade incomplete
# 0
# 5 17 :
# cascade incomplete
# 0
# 5 18 :
# cascade incomplete
# 0
# 5 19 :
# cascade incomplete
# 0
# 6 7 :
# cascade incomplete
# 0
# 6 8 :
# cascade incomplete
# 0
# 6 9 :
# cascade incomplete
# 0
# 6 10 :
# cascade incomplete
# 0
# 6 11 :
# cascade incomplete
# 0
# 6 12 :
# cascade incomplete
# 0
# 6 13 :
# cascade incomplete
# 0
# 6 14 :
# cascade incomplete
# 0
# 6 15 :
# cascade incomplete
# 0
# 6 16 :
# cascade incomplete
# 0
# 6 17 :
# cascade incomplete
# 0
# 6 18 :
# cascade incomplete
# 0
# 6 19 :
# cascade incomplete
# 0
# 7 8 :
# cascade incomplete
# 0
# 7 9 :
# cascade incomplete
# 0
# 7 10 :
# cascade incomplete
# 0
# 7 11 :
# cascade incomplete
# 0
# 7 12 :
# cascade incomplete
# 0
# 7 13 :
# cascade incomplete
# 0
# 7 14 :
# cascade incomplete
# 0
# 7 15 :
# cascade incomplete
# 0
# 7 16 :
# cascade incomplete
# 0
# 7 17 :
# cascade incomplete
# 0
# 7 18 :
# cascade incomplete
# 0
# 7 19 :
# cascade incomplete
# 0
# 8 9 :
# cascade incomplete
# 0
# 8 10 :
# cascade incomplete
# 0
# 8 11 :
# cascade incomplete
# 0
# 8 12 :
# cascade incomplete
# 0
# 8 13 :
# cascade incomplete
# 0
# 8 14 :
# cascade incomplete
# 20
# 8 15 :
# cascade incomplete
# 0
# 8 16 :
# cascade incomplete
# 0
# 8 17 :
# cascade complete with size:  20
# 8 18 :
# cascade incomplete
# 0
# 8 19 :
# cascade incomplete
# 0
# 9 10 :
# cascade complete with size:  20
# 9 11 :
# cascade incomplete
# 20
# 9 12 :
# cascade incomplete
# 0
# 9 13 :
# cascade incomplete
# 20
# 9 14 :
# cascade incomplete
# 0
# 9 15 :
# cascade incomplete
# 0
# 9 16 :
# cascade incomplete
# 0
# 9 17 :
# cascade incomplete
# 0
# 9 18 :
# cascade incomplete
# 0
# 9 19 :
# cascade incomplete
# 0
# 10 11 :
# cascade complete with size:  20
# 10 12 :
# cascade incomplete
# 0
# 10 13 :
# cascade incomplete
# 20
# 10 14 :
# cascade incomplete
# 0
# 10 15 :
# cascade incomplete
# 0
# 10 16 :
# cascade incomplete
# 0
# 10 17 :
# cascade complete with size:  20
# 10 18 :
# cascade incomplete
# 0
# 10 19 :
# cascade incomplete
# 20
# 11 12 :
# cascade incomplete
# 0
# 11 13 :
# cascade incomplete
# 20
# 11 14 :
# cascade incomplete
# 0
# 11 15 :
# cascade incomplete
# 0
# 11 16 :
# cascade incomplete
# 0
# 11 17 :
# cascade incomplete
# 0
# 11 18 :
# cascade incomplete
# 0
# 11 19 :
# cascade incomplete
# 20
# 12 13 :
# cascade incomplete
# 0
# 12 14 :
# cascade incomplete
# 0
# 12 15 :
# cascade incomplete
# 0
# 12 16 :
# cascade incomplete
# 0
# 12 17 :
# cascade incomplete
# 0
# 12 18 :
# cascade incomplete
# 0
# 12 19 :
# cascade incomplete
# 0
# 13 14 :
# cascade incomplete
# 0
# 13 15 :
# cascade incomplete
# 0
# 13 16 :
# cascade incomplete
# 0
# 13 17 :
# cascade incomplete
# 0
# 13 18 :
# cascade incomplete
# 0
# 13 19 :
# cascade incomplete
# 0
# 14 15 :
# cascade incomplete
# 0
# 14 16 :
# cascade incomplete
# 0
# 14 17 :
# cascade complete with size:  20
# 14 18 :
# cascade incomplete
# 20
# 14 19 :
# cascade incomplete
# 0
# 15 16 :
# cascade incomplete
# 0
# 15 17 :
# cascade incomplete
# 0
# 15 18 :
# cascade incomplete
# 20
# 15 19 :
# cascade incomplete
# 0
# 16 17 :
# cascade incomplete
# 0
# 16 18 :
# cascade incomplete
# 0
# 16 19 :
# cascade incomplete
# 0
# 17 18 :
# cascade incomplete
# 0
# 17 19 :
# cascade incomplete
# 0
# 18 19 :
# cascade incomplete
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/somy/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# ~/somy/lib/python3.6/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/somy/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/somy/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-3d2273df5f6b> in <module>
#       6 while(t):
#       7
# ----> 8     b = int(input('Enter PAYOFF for Initial bahaviour: '))
#       9     a = int(input('Enter PAYOFF for New bahaviour: '))
#      10
#
# ~/somy/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     857             self._parent_ident,
#     858             self._parent_header,
# --> 859             password=False,
#     860         )
#     861
#
# ~/somy/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     887             except KeyboardInterrupt:
#     888                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 889                 raise KeyboardInterrupt
#     890             else:
#     891                 break
#
# KeyboardInterrupt:

# %%
# for u in g.nodes():
#     for v in g.nodes():
#         if u<v:
#             print(u,v, ':')
#             list1 = []
#             list1.append(u)
#             list1.append(v)
            
            
#             action1 = "A"
#             action2 = "B"
#             for each in g.nodes():
#                 g.nodes[each]['action'] = action2
                
#             for each in list1:
#                 g.nodes[each]['action'] = action1 
                
#             flag =0
#             count =0
#             while(1):
#                 flag = terminate(g, count)
#                 if flag==1:
#                     break
#                 count = count+1
#                 action_dict  = recalculate_options(g)
#                 reset_node_attributes(g, action_dict)
#             colors = get_colors(g)

#             c =terminate_1('A', g)
#             if c==1:
#                 print('cascade complete')
#             else:
#                 print('cascade incomplete') 

# #nx.draw(g,node_color= colors , node_size=800,with_labels=True)
# #plt.show()
