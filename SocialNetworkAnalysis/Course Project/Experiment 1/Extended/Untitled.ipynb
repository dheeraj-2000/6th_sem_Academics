# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/home/dheeraj/my_projects/my_project_env/practice/6th_sem_Academics/SocialNetworkAnalysis/Course Project/Experiment 1/Extended/weblog/shell_7.csv",encoding = "ISO-8859-1")
df
# Out:
#     Unnamed: 0  node  inspow
# 0            1     3     490
# 1            2     8     492
# 2            3     9     504
# 3            4    11     494
# 4            5    21     507
# 5            6    70     496
# 6            7    74     508
# 7            8    84     511
# 8            9    88     523
# 9           10   157     501
# 10          11   176     516
# 11          12   186     504
# 12          13   188     519
# 13          14   208     501
# 14          15   254     514
# 15          16   266     516
# 16          17   274     523
# 17          18   279     496
# 18          19   303     504
# 19          20   308     499
# 20          21   318     504
# 21          22   319     505
# 22          23   327     499
# 23          24   328     518
# 24          25   335     503
# 25          26   349     498
# 26          27   357     497
# 27          28   375     501
# 28          29   379     512
# 29          30   383     502
# 30          31   386     500
# ...

# %%
df1= pd.DataFrame(df)
df1['Diffusion_Capacity'] = df1["inspow"]

# %%
df1.plot( x='node', y='Diffusion_Capacity', kind='bar',figsize=(12, 8), edgecolor='k', color= "lightgreen")
plt.xlabel('Nodes in shell 7', fontsize =14)
plt.ylabel('Diffusion Capacity',fontsize =14)
plt.title('Diffusion Capacity of each Nodes in shell 7 (considered as Pseudocore)\n of Weblog network ',fontweight='bold',fontsize =16)
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 10
plt.ylim((0,650))
plt.legend(["Number of nodes"], prop={"size":10})

plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)
# plt.get_xticklabels()[1].set_fontweight("bold")
