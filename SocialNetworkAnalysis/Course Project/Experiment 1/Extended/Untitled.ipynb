# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/home/dheeraj/my_projects/my_project_env/practice/6th_sem_Academics/SocialNetworkAnalysis/Course Project/Experiment 1/Extended/weblog/shell7/shell_7_nodes_pow.csv",encoding = "ISO-8859-1")
df
# Out:
#     Unnamed: 0  node  at_point_10  at_point_25  at_point_40  at_point_50  \
# 0            1     3          136          359          451          490
# 1            2     8            1          383          450          492
# 2            3     9          148          360          437          504
# 3            4    11            1          374          473          494
# 4            5    21            1          365          448          507
# 5            6    70          149          361          470          496
# 6            7    74            7          337          460          508
# 7            8    84            1          346          447          511
# 8            9    88            2          361          460          523
# 9           10   157            1            1          449          501
# 10          11   176          172          357          461          516
# 11          12   186          128          372          445          504
# ...

# %%
node = df["node"]
y_1 = df["at_point_10"]
y_25 = df["at_point_25"]

# %%
plt.plot(node, y_1, label="line1", color="#f781bf")
plt.xlim((1,648))
plt.ylim((-200,620))
plt.plot(node, y_25, label="line2", color="#a65628")
