# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/home/dheeraj/my_projects/my_project_env/practice/6th_sem_Academics/SocialNetworkAnalysis/Course Project/Experiment 1/Extended/shell_30.csv",encoding = "ISO-8859-1")
df
# Out:
#     Unnamed: 0  node  inspow
# 0            1   388    3949
# 1            2   393    3955
# 2            3   405    3962
# 3            4   409    3896
# 4            5   420    3941
# 5            6   431    3945
# 6            7   433    3947
# 7            8   440    3947
# 8            9   445    3939
# 9           10   494    3952
# 10          11   524    3886
# 11          12   538    3945
# 12          13   546    3935
# 13          14   557    3937
# 14          15   564    3962
# 15          16  1216    3939
# 16          17  1266    3942
# 17          18  1351    3898
# 18          19  1636    3954
# 19          20  1707    3901
# 20          21  1729    3960
# 21          22  1775    3946
# 22          23  1847    3951
# 23          24  1908    3942
# 24          25  1943    3946
# 25          26  2026    3895
# 26          27  2627    3895
# 27          28  2781    3944
# 28          29  2908    3944
# 29          30  3090    3957
# 30          31  3136    3948
# ...

# %%
df1= pd.DataFrame(df)
df1['Diffusion_Capacity'] = df1["inspow"]

# %%
df1.plot( x='node', y='Diffusion_Capacity', kind='bar',figsize=(10, 8), edgecolor='k', color= "lightgreen")
plt.xlabel('Nodes in shell 30', fontsize =14)
plt.ylabel('Diffusion Capacity',fontsize =14)
plt.title('Diffusion Capacity of each Nodes in shell 30 (considered \nas Pseudocore) of Facebook friendship network ',fontweight='bold',fontsize =16)
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 10
plt.ylim((0,5000))
plt.legend(["Number of nodes"], prop={"size":10})

plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)
# plt.get_xticklabels()[1].set_fontweight("bold")
