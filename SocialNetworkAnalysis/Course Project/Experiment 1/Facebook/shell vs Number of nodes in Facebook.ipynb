# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/home/dheeraj/my_projects/my_project_env/practice/6th_sem_Academics/SocialNetworkAnalysis/Course Project/Experiment 1/Facebook/shellvsNodeC.csv",encoding = "ISO-8859-1")
df
# Out:
#     Unnamed: 0  shell  NodeCount
# 0            1      1         75
# 1            2      2        108
# 2            3      3        102
# 3            4      4        120
# 4            5      5        134
# ..         ...    ...        ...
# 91          92     92          4
# 92          93     93          3
# 93          94     94          2
# 94          95     95          7
# 95          96     96        158
#
# [96 rows x 3 columns]

# %%
df1= pd.DataFrame(df)
df1['Number_of_Nodes'] = df1["NodeCount"]

# %%
df1.plot( x='shell', y='Number_of_Nodes', kind='bar',figsize=(18, 8), edgecolor='k', color= "lightgreen")

plt.xlabel('Shell Number', fontsize=20)
plt.ylabel('Number of Nodes', fontsize=20)
plt.title('Shell number vs Number of Nodes in Facebook friendship network', fontsize=20,fontweight='bold')
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)

# %%
df1.plot( x='shell', y='Number_of_Nodes', kind='bar',figsize=(18, 8), edgecolor='k', color= "lightgreen")
plt.xlabel('Shell Number', fontsize =18)
plt.ylabel('Number of nodes',fontsize =18)
plt.title('Shell number vs Number of Nodes in Facebook friendship network',fontweight='bold',fontsize =20)
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 10

plt.legend(["Number of nodes"], prop={"size":15})

plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)
# plt.get_xticklabels()[1].set_fontweight("bold")
