# %%
import numpy as np
import random
import matplotlib.pyplot as plt

x = np.arange(0, 2*np.pi, 0.1);
N = 100
y = np.sin(x)

plt.plot(x,y)

i=N
j=0
D = np.zeros((N,63))
while(i):
    t = random.choices(x,k = 2)
    yt = np.sin(t)
    y = 0*x + np.mean(yt)
    #for k in range(x):
    #D[i,:] = y
    plt.plot(x,y,color='k')
    j=j+1
    i=i-1

# %%
z = np.mean(yt)

# %%
z
# Out:
# -0.08979104077604885
