# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# %%
nx = np.linspace(0,6.2,10)
x = np.linspace(0,6.2,100)
y = np.sin(x)
e = np.sin(nx) + np.random.normal(0,0.15,10)

# %%
#plt.plot(x,y)
plt.scatter(nx,e)
plt.plot(x,y)

# %%
def calculate(x1,p):
    rx = []
    for i in x1:
        cx = []
        for j in range(p):
            cx.append(i**j)
        rx.append(cx)
    return pd.DataFrame(rx)

# %%
df = calculate(nx,5)
df
# Out:
#      0         1          2           3            4
# 0  1.0  0.000000   0.000000    0.000000     0.000000
# 1  1.0  0.688889   0.474568    0.326925     0.225215
# 2  1.0  1.377778   1.898272    2.615396     3.603435
# 3  1.0  2.066667   4.271111    8.826963    18.242390
# 4  1.0  2.755556   7.593086   20.923171    57.654961
# 5  1.0  3.444444  11.864198   40.865569   140.759183
# 6  1.0  4.133333  17.084444   70.615704   291.878242
# 7  1.0  4.822222  23.253827  112.135122   540.740478
# 8  1.0  5.511111  30.372346  167.385372   922.479382
# 9  1.0  6.200000  38.440000  238.328000  1477.633600

# %%
w = np.matmul(np.linalg.inv(np.matmul(np.transpose(df.values),df.values)),np.matmul(np.transpose(df.values),e))

# %%
w
# Out:
# array([ 0.11491455,  1.23698169, -0.44692123, -0.00628975,  0.00728853])

# %%
df1 = calculate(x,5)
plt.plot(x,np.matmul(df1.values,w),color = "green")
plt.scatter(nx,e)
plt.plot(x,y,color = "red")

# %%
df1
# Out:
#       0         1          2           3            4
# 0   1.0  0.000000   0.000000    0.000000     0.000000
# 1   1.0  0.062626   0.003922    0.000246     0.000015
# 2   1.0  0.125253   0.015688    0.001965     0.000246
# 3   1.0  0.187879   0.035298    0.006632     0.001246
# 4   1.0  0.250505   0.062753    0.015720     0.003938
# 5   1.0  0.313131   0.098051    0.030703     0.009614
# 6   1.0  0.375758   0.141194    0.053055     0.019936
# 7   1.0  0.438384   0.192180    0.084249     0.036933
# 8   1.0  0.501010   0.251011    0.125759     0.063007
# 9   1.0  0.563636   0.317686    0.179059     0.100924
# 10  1.0  0.626263   0.392205    0.245623     0.153825
# 11  1.0  0.688889   0.474568    0.326925     0.225215
# 12  1.0  0.751515   0.564775    0.424437     0.318971
# 13  1.0  0.814141   0.662826    0.539634     0.439339
# 14  1.0  0.876768   0.768722    0.673990     0.590933
# 15  1.0  0.939394   0.882461    0.828978     0.778737
# 16  1.0  1.002020   1.004044    1.006073     1.008105
# 17  1.0  1.064646   1.133472    1.206747     1.284759
