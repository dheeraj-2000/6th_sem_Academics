# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
from scipy.stats import norm

# %%
nx = np.linspace(0,6.2,10)
x = np.linspace(0,6.2,100)
y = np.sin(x)
e = np.sin(nx) + np.random.normal(0,0.15,10)

# %%
#plt.plot(x,y)
plt.scatter(nx,e)
plt.plot(x,y)

# %%
def calculate(x1,p):
    m = np.linspace(0, 6.5, p)
    #m = (1.5, 5)
    rx = []
    for i in x1:
        cx = []
        for j in m:
            cx.append(norm.pdf(i,j,1))
        rx.append(cx)
    return pd.DataFrame(rx)
    rx

# %%
#for i in range(11):
#    df = calculate(nx,1)
 #   df

# %%
w = np.matmul(np.linalg.inv(np.matmul(np.transpose(df.values),df.values)),np.matmul(np.transpose(df.values),e))

# %%
w
# Out:
# array([ 2.43918003, -2.06386652])

# %%
for i in range(11):
    df = calculate(nx,i)
    w = np.matmul(np.linalg.inv(np.matmul(np.transpose(df.values),df.values)),np.matmul(np.transpose(df.values),e))
    df1 = calculate(x,i)
    plt.plot(x,np.matmul(df1.values,w),color = "green")
    plt.scatter(nx,e)
    plt.plot(x,y,color = "red")
    plt.show()

# %%
df1
# Out:
#                0             1         2         3         4         5  \
# 0   3.989423e-01  3.073583e-01  0.140556  0.038153  0.006147  0.000588
# 1   3.981607e-01  3.209494e-01  0.153562  0.043612  0.007352  0.000736
# 2   3.958252e-01  3.338295e-01  0.167115  0.049657  0.008758  0.000917
# 3   3.919630e-01  3.458673e-01  0.181152  0.056318  0.010393  0.001138
# 4   3.866192e-01  3.569366e-01  0.195600  0.063623  0.012284  0.001408
# ..           ...           ...       ...       ...       ...       ...
# 95  8.215990e-09  4.650464e-07  0.000016  0.000312  0.003688  0.025914
# 96  5.649271e-09  3.345585e-07  0.000012  0.000245  0.003039  0.022340
# 97  3.869204e-09  2.397422e-07  0.000009  0.000192  0.002494  0.019184
# 98  2.639657e-09  1.711250e-07  0.000007  0.000150  0.002039  0.016409
# 99  1.793784e-09  1.216688e-07  0.000005  0.000117  0.001660  0.013980
#
#            6         7             8             9
# 0   0.000033  0.000001  2.248772e-08  2.669557e-10
# 1   0.000044  0.000002  3.222843e-08  4.002912e-10
# 2   0.000057  0.000002  4.600759e-08  5.978739e-10
# 3   0.000074  0.000003  6.542091e-08  8.894875e-10
# 4   0.000096  0.000004  9.266172e-08  1.318156e-09
# ..       ...       ...           ...           ...
# 95  0.108075  0.267536  3.931037e-01  3.428486e-01
# 96  0.097481  0.252474  3.881370e-01  3.541795e-01
# 97  0.087580  0.237327  3.817329e-01  3.644527e-01
# 98  0.078377  0.222216  3.739650e-01  3.735560e-01
# 99  0.069867  0.207253  3.649210e-01  3.813878e-01
#
# [100 rows x 10 columns]
