# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
x = np.linspace(0, 2*3.14, 10)
y = np.sin(x)

# %%
plt.scatter(x, y)

# %%
y_function = y + np.random.normal(0, 2*3.14,10)

# %%
plt.scatter(x, y)
#plt.scatter(x, y_function)

# %%
w = 100
dict[]
# Out:
#   File "<ipython-input-57-55832ec79c17>", line 2
#     dict[]:
#          ^
# SyntaxError: invalid syntax
