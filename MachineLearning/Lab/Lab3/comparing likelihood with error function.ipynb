# %%
import numpy as np   
import matplotlib.pyplot as plt 
from mpl_toolkits import mplot3d
from scipy.stats import norm

# %%
x = np.linspace(-10, 10,100)
y = 2*x +4
a0 = np.linspace(-100,100,100)
a1 = np.linspace(-100,100,100)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random
random.seed(1)
noise = np.random.randn(10)
m = 1
x = np.linspace(1,10,10)
y = m*x + 5
plt.plot(x,y)
#e = m*x + 5 + noise #represents equation with noise
#plt.scatter(x,e,color = "red")
w1 = np.linspace(-10,10,100)
w0 = np.linspace(-10,10,100)
W0, W1 = np.meshgrid (w0, w1)
l = 0
it = len(x)
for i in range(it):
    l += (W1*x[i] + W0 - y[i])**2 #calculates error value for equation having loss
plt.gca().set_aspect('equal',adjustable = 'box')
plt.draw()
plt.contour(W0,W1,l,levels = [i for i in np.arange(-100,100,60)],colors = "red")
l1 = 0
for i in range(it):
    l1 += (W1*x[i] + W0 - y[i])**2
ax.plot_surface(W0, W1, l1, cmap='autumn', rstride=1, cstride=1, edgecolor='none')

# %%
def erro(a1, a2, x, y):
    e = 0
    for i in range(len(x)):
        e += ((a1*x[i] - a0) - y[i] )**2
    return e

# %%
A0,A1 = np.meshgrid(a0,a1)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
mycmap = plt.get_cmap('gist_earth')
#ax.plot_surface(a1, a0, erro(A1, A0, x, y),rstride=1, cstride=1, color='b', alpha=0.5)
ax.plot_surface(a1, a0, erro(A1, A0, x, y), cmap='winter', rstride=1, cstride=1, edgecolor='none')

# %%
def like(x,y ,a0 , a1):
    ll=0 
    for i ,j in zip(x,y):
        ll+= np.log(norm.pdf(ww0*i+ww1,j,1))
    return ll

# %%
ww0,ww1= np.meshgrid(a0,a1)
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
mycmap = plt.get_cmap('gist_earth')
#ax.plot_surface(ww0, ww1, like(x,y,ww0,ww1), cmap = mycmap)
ax.plot_surface(ww0, ww1, like(x,y,ww0,ww1), cmap='winter', rstride=1, cstride=1, edgecolor='none')
# Out:
# /home/dheeraj/my_projects/my_project_env/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
plt.xlabel('w0')
plt.ylabel('w1')
plt.title('Combined Surface graph')
ax.plot_surface(W0, W1, l, cmap='winter', rstride=1, cstride=1, edgecolor='none')
ax.plot_surface(W0, W1, l1, cmap='autumn', rstride=1, cstride=1, edgecolor='none')
# Out:
# /home/dheeraj/my_projects/my_project_env/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
