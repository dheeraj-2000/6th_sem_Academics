# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1bd048e6abf6> in <module>
# ----> 1 a = np.linspace(-7,13,100)
#       2 print(a)
#
# NameError: name 'np' is not defined

# %%
import numpy as np   
import matplotlib.pyplot as plt 
from mpl_toolkits import mplot3d

# %%
x = np.linspace(1, 11,10)
y = 5*x +1

# %%
def erro(a1, a2, x, y):
    e = 0
    for i in range(len(x)):
        e += ((a1*x[i] - a0) - y[i] )**2
    return e

# %%
a0 = np.linspace(-100,100,100)
a1 = np.linspace(-100,100,100) 
A0,A1 = np.meshgrid(a0,a1)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
mycmap = plt.get_cmap('gist_earth')
ax.plot_surface(a1, a0, erro(A1, A0, x, y),rstride=1, cstride=1, color='b', alpha=0.5)

# %%
# Out:
#   File "<ipython-input-10-de3bb57d0f7b>", line 1
#     def erro()
#               ^
# SyntaxError: invalid syntax
